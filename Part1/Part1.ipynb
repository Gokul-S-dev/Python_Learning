# %%
# # # What is python?
# # Python is a popular programming language.Guido Van Rossum in 1991
# used in
#   web development
#   Software development
#   mathematics
#   system scripting

# %%
# #T1:Output
# Print Text

# Text in python must inside quotes.You can use either " double quotes or ' single quotes.

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
# multiple words in same line
print("Hello first line-->",end=" ")
print("This is second line")
# Out:
# Hello first line--> This is second line

# %%
# Print Numbers
print(5)
print(5+5)
# Mix text and numbers
print("I am ",35," years old .")
# Out:
# 5
# 10
# I am  35  years old .

# %%
# Variables
# - Variables are containers for storing data values

x=5
y="Gokul"
print("A num ",x,"A String",y)
# Out:
# A num  5 A String Gokul

# %%
Variables are case sensitive

a=4
A="Gokul"
b=str(a)

# %%
# Casting
x=str(3)
y=int(5)
z=float(3)

print(type(z))
print(type(y))
print(type(x))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
Multi Words Variable Name

# %%
# Camel case
myVariableName = "John"

# %%
# Pascal Case
MyVariableName = "John"

# %%
# Snake Case
my_variable_name = "John"

# %%
# Many Values to Multiple Variables

x,y,z="A","B","C"
print(x,end=" ")
print(y)
print(z)

# One value to multiple variables
x=y=z="Gokul"
print(x,y,z)
# Out:
# A B
# C
# Gokul Gokul Gokul

# %%
Built-in DataTypes

Text Type : str
Numeric Type : int,float,complex
Sequence Type : list,tuple,range
Mapping Type : dict
Set Types : set, frozenset
Boolean Type : bool
Binary Type : bytes,bytearray,memoryview
None Type : NoneType

# %%
#Random Number
import random

print(random.randrange(1,10))
# Out:
# 2

# %%
#Casting
x=int(2.5)
y=float(5)
print(x,y)
# Out:
# 2 5.0
